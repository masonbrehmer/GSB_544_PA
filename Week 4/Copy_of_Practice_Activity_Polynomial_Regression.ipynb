# %% [markdown]
# # Palmer Penguins Modeling
#
# Import the Palmer Penguins dataset and print out the first few rows.
#
# Suppose we want to predict `bill_depth_mm` using the other variables in the dataset.
#
# Which variables would we need to **dummify**?

# %%
#pip install PalmerPenguins

# %%
#pip install scikit-learn

# %%
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
from palmerpenguins import load_penguins
penguins = load_penguins()
penguins.head()
# Out:
#   species     island  bill_length_mm  ...  body_mass_g     sex  year
# 0  Adelie  Torgersen            39.1  ...       3750.0    male  2007
# 1  Adelie  Torgersen            39.5  ...       3800.0  female  2007
# 2  Adelie  Torgersen            40.3  ...       3250.0  female  2007
# 3  Adelie  Torgersen             NaN  ...          NaN     NaN  2007
# 4  Adelie  Torgersen            36.7  ...       3450.0  female  2007
#
# [5 rows x 8 columns]

# %% [markdown]
# We would want to dummify the species variable.

# %%
# Code Here

# %% [markdown]
# Let's use `bill_length_mm` to predict `bill_depth_mm`. Prepare your data and fit the following models on the entire dataset:
#
# * Simple linear regression (e.g. straight-line) model
# * Quadratic (degree 2 polynomial) model
# * Cubic (degree 3 polynomial) model
# * Degree 10 polynomial model
#
# Make predictions for each model and plot your fitted models on the scatterplot.

# %%
# Prepare the data: select relevant columns and handle missing values
penguins_cleaned = penguins[['bill_length_mm', 'bill_depth_mm']].dropna()

# Define features (X) and target (y)
X = penguins_cleaned[['bill_length_mm']]
y = penguins_cleaned['bill_depth_mm']

# Simple linear regression model
slr = LinearRegression()
slr.fit(X, y)

# Display the coefficients
print("Simple Linear Regression Model Coefficients:")
print(f"Intercept: {slr.intercept_}")
print(f"Coefficient: {slr.coef_[0]}")
# Out:
# Simple Linear Regression Model Coefficients:
# Intercept: 20.885468318532755
# Coefficient: -0.08502128077717656

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate a range of bill lengths for plotting the fitted line
# Use the same X_plot for all models
X_plot = pd.DataFrame({'bill_length_mm': np.linspace(X.min(), X.max(), 100).flatten()})

# Make predictions for each model
y_plot_slr = slr.predict(X_plot)
# Out:
# array([18.15628521, 18.13266818, 18.10905116, 18.08543414, 18.06181712,
#        18.03820009, 18.01458307, 17.99096605, 17.96734903, 17.943732  ,
#        17.92011498, 17.89649796, 17.87288094, 17.84926391, 17.82564689,
#        17.80202987, 17.77841285, 17.75479582, 17.7311788 , 17.70756178,
#        17.68394476, 17.66032773, 17.63671071, 17.61309369, 17.58947667,
#        17.56585964, 17.54224262, 17.5186256 , 17.49500858, 17.47139155,
#        17.44777453, 17.42415751, 17.40054049, 17.37692347, 17.35330644,
#        17.32968942, 17.3060724 , 17.28245538, 17.25883835, 17.23522133,
#        17.21160431, 17.18798729, 17.16437026, 17.14075324, 17.11713622,
#        17.0935192 , 17.06990217, 17.04628515, 17.02266813, 16.99905111,
#        16.97543408, 16.95181706, 16.92820004, 16.90458302, 16.88096599,
#        16.85734897, 16.83373195, 16.81011493, 16.7864979 , 16.76288088,
#        16.73926386, 16.71564684, 16.69202981, 16.66841279, 16.64479577,
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate a range of bill lengths for plotting the fitted line
# Use the same X_plot for all models
X_plot = pd.DataFrame({'bill_length_mm': np.linspace(X.min(), X.max(), 100).flatten()})

# Make predictions for each model
y_plot_slr = slr.predict(X_plot)

# Need to transform X_plot for polynomial models
X_plot_poly2 = poly2.transform(X_plot)
y_plot_quadratic = quadratic_model.predict(X_plot_poly2)

X_plot_poly3 = poly3.transform(X_plot)
y_plot_cubic = cubic_model.predict(X_plot_poly3)

X_plot_poly10 = poly10.transform(X_plot)
y_plot_poly10 = poly10_model.predict(X_plot_poly10)


# Plot the original data and the fitted lines
plt.figure(figsize=(12, 8))
plt.scatter(X, y, label='Original Data', alpha=0.6)
plt.plot(X_plot, y_plot_slr, color='red', linestyle='-', label='Simple Linear Regression')
plt.plot(X_plot, y_plot_quadratic, color='green', linestyle='-', label='Quadratic Model')
plt.plot(X_plot, y_plot_cubic, color='purple', linestyle='-', label='Cubic Model')
plt.plot(X_plot, y_plot_poly10, color='orange', linestyle='-', label='Degree 10 Model')

plt.xlabel('Bill Length (mm)')
plt.ylabel('Bill Depth (mm)')
plt.title('Polynomial Regression Model Fits')
plt.legend()
plt.grid(True)
plt.ylim(penguins_cleaned['bill_depth_mm'].min() - 1, penguins_cleaned['bill_depth_mm'].max() + 1) # Adjust y-axis limits
plt.xlim(penguins_cleaned['bill_length_mm'].min() - 1, penguins_cleaned['bill_length_mm'].max() + 1) # Adjust x-axis limits
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate a range of bill lengths for plotting the fitted line
X_plot = pd.DataFrame({'bill_length_mm': np.linspace(X.min(), X.max(), 100).flatten()})

# Make predictions using the simple linear regression model
y_plot_slr = slr.predict(X_plot)

# Plot the original data and the fitted line
plt.figure(figsize=(10, 6))
plt.scatter(X, y, label='Original Data', alpha=0.6)
plt.plot(X_plot, y_plot_slr, color='red', label='Simple Linear Regression')
plt.xlabel('Bill Length (mm)')
plt.ylabel('Bill Depth (mm)')
plt.title('Simple Linear Regression Fit')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate a range of bill lengths for plotting the fitted line
X_plot = pd.DataFrame({'bill_length_mm': np.linspace(X.min(), X.max(), 100).flatten()})

# Need to transform X_plot for polynomial models
X_plot_poly2 = poly2.transform(X_plot)
y_plot_quadratic = quadratic_model.predict(X_plot_poly2)

# Plot the original data and the fitted line
plt.figure(figsize=(10, 6))
plt.scatter(X, y, label='Original Data', alpha=0.6)
plt.plot(X_plot, y_plot_quadratic, color='green', label='Quadratic Model')
plt.xlabel('Bill Length (mm)')
plt.ylabel('Bill Depth (mm)')
plt.title('Quadratic Regression Fit')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate a range of bill lengths for plotting the fitted line
X_plot = pd.DataFrame({'bill_length_mm': np.linspace(X.min(), X.max(), 100).flatten()})

# Need to transform X_plot for polynomial models
X_plot_poly3 = poly3.transform(X_plot)
y_plot_cubic = cubic_model.predict(X_plot_poly3)

# Plot the original data and the fitted line
plt.figure(figsize=(10, 6))
plt.scatter(X, y, label='Original Data', alpha=0.6)
plt.plot(X_plot, y_plot_cubic, color='purple', label='Cubic Model')
plt.xlabel('Bill Length (mm)')
plt.ylabel('Bill Depth (mm)')
plt.title('Cubic Regression Fit')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate a range of bill lengths for plotting the fitted line
X_plot = pd.DataFrame({'bill_length_mm': np.linspace(X.min(), X.max(), 100).flatten()})

# Need to transform X_plot for polynomial models
X_plot_poly10 = poly10.transform(X_plot)
y_plot_poly10 = poly10_model.predict(X_plot_poly10)

# Plot the original data and the fitted line
plt.figure(figsize=(10, 6))
plt.scatter(X, y, label='Original Data', alpha=0.6)
plt.plot(X_plot, y_plot_poly10, color='orange', label='Degree 10 Model')
plt.xlabel('Bill Length (mm)')
plt.ylabel('Bill Depth (mm)')
plt.title('Degree 10 Polynomial Regression Fit')
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures

poly2 = PolynomialFeatures(degree=2)
X_poly2 = poly2.fit_transform(X)

quadratic_model = LinearRegression()
quadratic_model.fit(X_poly2, y)

# Display the coefficients
print("Quadratic Regression Model Coefficients:")
print(f"Intercept: {quadratic_model.intercept_}")
print(f"Coefficients: {quadratic_model.coef_}")
# Out:
# Quadratic Regression Model Coefficients:
# Intercept: 49.8810032211198
# Coefficients: [ 0.         -1.42149289  0.0151644 ]

# %%
from sklearn.preprocessing import PolynomialFeatures

poly3 = PolynomialFeatures(degree=3)
X_poly3 = poly3.fit_transform(X)

cubic_model = LinearRegression()
cubic_model.fit(X_poly3, y)

# Display the coefficients
print("\nCubic Regression Model Coefficients:")
print(f"Intercept: {cubic_model.intercept_}")
print(f"Coefficients: {cubic_model.coef_}")
# Out:
# Cubic Regression Model Coefficients:
# Intercept: -73.59178504898297
# Coefficients: [ 0.00000000e+00  7.00494111e+00 -1.74355549e-01  1.40554271e-03]

# %%
poly10 = PolynomialFeatures(degree=10)
X_poly10 = poly10.fit_transform(X)

poly10_model = LinearRegression()
poly10_model.fit(X_poly10, y)

# Output the coefficients as a numpy array
print(poly10_model.coef_)
# Out:
# [ 0.00000000e+00 -2.23594513e-14  4.56963948e-12  1.54316189e-10
#   3.99369189e-09  7.58162706e-08  8.32820273e-07 -5.95935634e-08
#   1.61049202e-09 -1.94392298e-11  8.82283808e-14]

# %% [markdown]
# * Are any of the models above underfitting the data? If so, which ones and how can you tell?
# * Are any of thhe models above overfitting the data? If so, which ones and how can you tell?
# * Which of the above models do you think fits the data best and why?
